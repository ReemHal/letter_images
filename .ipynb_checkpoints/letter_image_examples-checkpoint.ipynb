# %% [markdown]
# ## Using the letter_image Class
#
# This notebook shows functions that process an image of a business letter in the letter_image class icluding: identifying the different parts of the letter in the image, showing those parts superimposed on the image, printing the text within each part, and displaying the ray text as detected by the OCR function (currently using tesseract).

# %% [markdown]
# ### Instantiate the letter_image object and process the image

# %%
import letter_image

# Directory containing the iamge
dataset_dir = "/media/datadr/datasets/letters"

# %%
img_name= "letter_1"

# Instantiate a letter_image object
letter_obj = letter_image.letter_image(dataset_dir, img_name)
# Identify the different parts in the image and the text within each part
letter_obj.process_letter()
# Out:
# heading
# part:heading from:0 to:1
# recipient
# part:recipient from:3 to:3
# body
# part:body from:5 to:11
# signature
# part:signature from:13 to:12

# %%
# letter_obj.clip is an array whose length is equal to the number of parts detected in the 
# image and contains the letter data
print("keys of each letter_obj.clip element",list(letter_obj.clip[0].keys()))
# Out:
# keys of each letter_obj.clip element ['contour', 'text', 'part']

# %% [markdown]
# ### Display the location of each letter part within the image

# %%
#Display where each detected part is located in the image
letter_obj.display_contours()

# %% [markdown]
# ### Display the text contained in each part of the letter

# %%
letter_obj.display_letter_parts()
# Out:
# 613 East Broadway, Room 120
# Glendale, California 91206-4399
# Tel, (8‘8) 548-2000 Fax (318) 5-13-3739
#
# www.c|.glcndalc.ca.us
#
# type:heading
# =============
# March 19, 2009
#
# type:date
# =============
# Mr. Paul Marcotte
#
# Director
#
# UC Davis Hubert H. Humphrey Fellowship Program
# University Outreach and International Programs
# University of California Davis
#
# Davis. CA 95818
#
# type:recipient
# =============
# Dear Paul‘
#
# type:greeting
# =============
# i would like to extend an offer of Professional Afﬁliation for Ruzanna Martirosyan to associate with
# the Parks. Recreation and Community Services of the City of Glendale, CA. We believe that she
# will gain both theoretical and practical skills of park management in Glendale and that we will
# beneﬁt from her presence and expertise with World Bank. UNDP and her parks at home.
#
# I propose that her afﬁliation commence on March 30, 2009 until June 5, 2009. It is expected that
# she will focus on'
#
# Learning the process used to develop a master plan for capital development
# Learning how programs and services are identiﬁed and prioritized
#
# Visiting speciﬁc ﬁeld sites to see practical implementation of capital improvement
# elements and selected services (29. selected trails)
#
# 3"!“7‘
#
# I believe that we can provide an excellent professional experience for her directly In her ﬁeld and
# career,
#
# it is our understanding that Ms, Martirosyan is fully funded and supponed with a stipend and
# travel/ﬁeld related oasis in connection with this afﬁliation. and that we are not required io provide
# additional funding for her participation in the program.
#
# Thank you and we look forward to working with you. your program and Ruzanna.
#
# type:body
# =============
# Sincerely
#
#
#
#
# Directgr of Par
#
# type:signature
# =============

# %% [markdown]
# ### Functions to view the raw image, contours, and text
#
# These functions are useful for debugging

# %% [markdown]
# #### Display the input image

# %%
letter_obj.display_letter()

# %% [markdown]
# #### Print the text within the image generated by the OCR function without segmenting the image

# %%
text = letter_obj.get_letter_text()
print(text)
# Out:
# CITY or GLENDALE. CALIFORNIA (:13 East Broadway. Ronni izu
# Parks. Recreation and Community Services Glendale. California 912(lfr4399
# 'l'cl, ltllll] 5-18-2000 Fax [Billy 5484789
#
# www.cl.g|oi1dalc.ca.iis
#
#
#
#
#
# March 19. 2009
#
# Mr. Paul Marcotte
#
# Director
#
# UC Davis Hubert H. Humphrey Fellowship Program
# University Outreach and International Programs
# University of California Davis
#
# Davis. CA 95816
#
# Dear Paul.
#
# l would like to extend an offer of Professional Afﬁliation for Ruzanna Martirosyan to associate with
# the Parks. Recreation and Community Services of the City of Glendale, CA. We believe that she
# will gain both theoretical and practical skills of park management in Glendale and that we will
# beneﬁt from her presence and expertise with World Bank. UNDP and her parks at home.
#
# i propose that her afﬁliation commence on March 30. 2009 until June 5. 2009. It is expected that
# she will focus on'
#
# 1. Learning the process used to develop a master plan for capital development
#
# 2. Learning how programs and services are identiﬁed and prioritized
#
# 3 Visiting speciﬁc ﬁeld sites to see practical implementation of capital improvement
# elements and selected services (eg. selected trails)
#
# I believe that we can provide an excellent professional experience for her directly in her ﬁeld and
# career,
#
# |t is our understanding that Ms, Martirosyan is fully funded and supported with a stipend and
# travel/ﬁeld related costs in connection with this afﬁliation. and that we are not required to provide
# additional funding for her participation in the program.
#
# Thank you and we look forward to working with you. your program and Ruzanna.
#
# Sincerely

# %% [markdown]
# #### Show the potential letter parts

# %%
import matplotlib.pyplot as plt 

# The get_contours function identifies blocks in the image that represent potentially semantically related text
contours = letter_obj.get_contours()

fig, ax=plt.subplots(figsize=(7,7))
ax.imshow(letter_obj.letter_img)
            
for contour in contours:
    ax.plot(contour[:, 1], contour[:, 0], linewidth=2)
plt.show()
